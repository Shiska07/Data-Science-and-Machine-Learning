# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Data/RestaurantVisitors.csv', index_col='date', parse_dates=True)
df.index.freq='D'

# %%
df.head()
# Out:
#              weekday  holiday    holiday_name  rest1  rest2  rest3  rest4  \
# date
# 2016-01-01    Friday        1  New Year's Day   65.0   25.0   67.0  139.0
# 2016-01-02  Saturday        0              na   24.0   39.0   43.0   85.0
# 2016-01-03    Sunday        0              na   24.0   31.0   66.0   81.0
# 2016-01-04    Monday        0              na   23.0   18.0   32.0   32.0
# 2016-01-05   Tuesday        0              na    2.0   15.0   38.0   43.0
#
#             total
# date
# 2016-01-01  296.0
# 2016-01-02  191.0
# 2016-01-03  202.0
# 2016-01-04  105.0
# 2016-01-05   98.0

# %%
# the 'holiday' column will be used as an exogenous variable in the tim eseries model
df.tail()
# Out:
#               weekday  holiday  holiday_name  rest1  rest2  rest3  rest4  \
# date
# 2017-05-27   Saturday        0            na    NaN    NaN    NaN    NaN
# 2017-05-28     Sunday        0            na    NaN    NaN    NaN    NaN
# 2017-05-29     Monday        1  Memorial Day    NaN    NaN    NaN    NaN
# 2017-05-30    Tuesday        0            na    NaN    NaN    NaN    NaN
# 2017-05-31  Wednesday        0            na    NaN    NaN    NaN    NaN
#
#             total
# date
# 2017-05-27    NaN
# 2017-05-28    NaN
# 2017-05-29    NaN
# 2017-05-30    NaN
# 2017-05-31    NaN

# %%
# drop missing data
df.dropna(inplace=True, axis = 0)
df.tail()
# Out:
#               weekday  holiday holiday_name  rest1  rest2  rest3  rest4  total
# date
# 2017-04-18    Tuesday        0           na   30.0   30.0   13.0   18.0   91.0
# 2017-04-19  Wednesday        0           na   20.0   11.0   30.0   18.0   79.0
# 2017-04-20   Thursday        0           na   22.0    3.0   19.0   46.0   90.0
# 2017-04-21     Friday        0           na   38.0   53.0   36.0   38.0  165.0
# 2017-04-22   Saturday        0           na   97.0   20.0   50.0   59.0  226.0

# %%
# change data type into integers
df.columns
# Out:
# Index(['weekday', 'holiday', 'holiday_name', 'rest1', 'rest2', 'rest3',
#        'rest4', 'total'],
#       dtype='object')

# %%
cols = ['rest1', 'rest2', 'rest3', 'rest4', 'total']

# %%
for col in cols:
    df[col] = df[col].astype(int)
    
df.head()
# Out:
#              weekday  holiday    holiday_name  rest1  rest2  rest3  rest4  \
# date
# 2016-01-01    Friday        1  New Year's Day     65     25     67    139
# 2016-01-02  Saturday        0              na     24     39     43     85
# 2016-01-03    Sunday        0              na     24     31     66     81
# 2016-01-04    Monday        0              na     23     18     32     32
# 2016-01-05   Tuesday        0              na      2     15     38     43
#
#             total
# date
# 2016-01-01    296
# 2016-01-02    191
# 2016-01-03    202
# 2016-01-04    105
# 2016-01-05     98

# %%
df['total'].plot(figsize = (12, 5), grid = True)

# %%
df.query('holiday==1').index
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-18', '2016-02-02', '2016-02-14',
#                '2016-02-15', '2016-03-17', '2016-03-25', '2016-03-27',
#                '2016-03-28', '2016-05-05', '2016-05-08', '2016-05-30',
#                '2016-06-19', '2016-07-04', '2016-09-05', '2016-10-10',
#                '2016-10-31', '2016-11-11', '2016-11-24', '2016-11-25',
#                '2016-12-24', '2016-12-25', '2016-12-31', '2017-01-01',
#                '2017-01-16', '2017-02-02', '2017-02-14', '2017-02-20',
#                '2017-03-17', '2017-04-14', '2017-04-16', '2017-04-17'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
#test the exogenous variable
ax = df['total'].plot(figsize = (16, 5))
for day in df.query('holiday==1').index:
    ax.axvline(x=day, color = 'k', alpha = 0.5);

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
res = seasonal_decompose(df['total'])
res.plot();

# %%
res.seasonal.plot(figsize = (18, 5))

# %% [markdown]
# ### Classic SARIMA Model

# %%
# train test split
train = df.iloc[:436]
test = df.iloc[436:]

# %%
start = len(train)
end = start + len(test) - 1

# %%
from pmdarima import auto_arima

# %%
auto_arima(df['total'], seasonal = True, m = 7).summary()
# Out:
# C:\Users\shisk\anaconda3\envs\tsa_course\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\shisk\anaconda3\envs\tsa_course\lib\site-packages\pmdarima\arima\auto.py:870: ModelFitWarning: Unable to fit ARIMA for order=(1, 0, 0) seasonal_order=(2, 0, 1, 7); data is likely non-stationary. (if you do not want to see these warnings, run with error_action="ignore")
#   ModelFitWarning)
# C:\Users\shisk\anaconda3\envs\tsa_course\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\shisk\anaconda3\envs\tsa_course\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ...

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model = SARIMAX(train['total'], order=(1,0,0), seasonal_order=(2,0,0,7), enforce_invertibility=False).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ...
# Dep. Variable:                             total   No. Observations:                  436
# Model:             SARIMAX(1, 0, 0)x(2, 0, 0, 7)   Log Likelihood               -2224.701
# Date:                           Thu, 31 Aug 2023   AIC                           4457.403
# Time:                                   21:47:43   BIC                           4473.713
# Sample:                               01-01-2016   HQIC                          4463.840
#                                     - 03-11-2017
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2212      0.047      4.711      0.000       0.129       0.313
# ar.S.L7        0.5063      0.036     14.187      0.000       0.436       0.576
# ...

# %%
pred = model.predict(start, end).rename('SARIMA Model')

# %%
test.total.plot(legend = True, figsize = (12,5))
pred.plot(legend = True)

# %%
# add holiday markers
ax = test.total.plot(legend = True, figsize = (12,5))
pred.plot(legend = True)

for day in test.query('holiday==1').index:
    ax.axvline(x=day, color = 'k', alpha = 0.8);

# %%
from statsmodels.tools.eval_measures import rmse

# %%
rmse(test['total'], pred)
# Out:
# 41.263154972797885

# %%
test['total'].mean()
# Out:
# 134.26190476190476

# %% [markdown]
# ### Training with exogenous variable 'Holiday'
# While using exogenous variables for building a model, we also need to know the values of exogenous variable for testing or future forecasting.

# %%
auto_arima(df['total'], exogenous=df[['holiday']], seasonal=True, m=7).summary()
# Out:
# C:\Users\shisk\anaconda3\envs\tsa_course\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\shisk\anaconda3\envs\tsa_course\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\shisk\anaconda3\envs\tsa_course\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\shisk\anaconda3\envs\tsa_course\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ...

# %%
model = SARIMAX(train['total'], exog=train[['holiday']], order=(0,0,1), seasonal_order=(2,0,0,7), enforce_invertibility=False).fit()

# %%
pred = model.predict(start, end, exog=test[['holiday']]).rename('SARIMA with exog')

# %%
test.total.plot(legend = True, figsize = (12,5))
pred.plot(legend = True)

# %%
# add holiday markers
ax = test.total.plot(legend = True, figsize = (12,5))
pred.plot(legend = True)

for day in test.query('holiday==1').index:
    ax.axvline(x=day, color = 'k', alpha = 0.8);

# %%
# calculate rmse
rmse(test['total'], pred)
# Out:
# 31.09251362899617

# %%
test['total'].mean()
# Out:
# 134.26190476190476

# %%
'''
RMSE is much lower than the classical SARIMA model. Using 'holiday' as exogenous variable has significantly
imporved model perforamce.
'''
